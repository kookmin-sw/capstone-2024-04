# %% [markdown]
# ## 아이컨택 모델 (Looking) 실험
# - https://github.com/vita-epfl/looking/tree/main?tab=readme-ov-file 저장소 코드 실험
# - 이미지를 불러와서, 포즈 정보를 바탕으로 사람이 카메라를 쳐다보는지, 아닌지를 판단하는 모델
# - 환경 설정은 되어있다 가정 (코랩 환경에서 파이썬 3.10.12 사용)

# %%
# !git clone https://github.com/vita-epfl/looking.git
# Out:
# Cloning into 'looking'...
# remote: Enumerating objects: 1688, done.
# remote: Total 1688 (delta 0), reused 0 (delta 0), pack-reused 1688
# Receiving objects: 100% (1688/1688), 74.52 MiB | 19.45 MiB/s, done.
# Resolving deltas: 100% (1169/1169), done.

# %%
cd /content/looking
# Out:
# /content/looking

# %%
pwd
# Out:
# '/content/looking'

# %%
# !pip install openpifpaf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.3/202.3 kB 1.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.2/166.2 kB 17.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 50.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# ...
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# ...
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# ...

# %%
# CPU를 사용해서 이미지에 대한 추론
# !python predict.py --images images/five_people.jpeg --device cpu --disable-cuda

# GPU에서 실험할 때는 아래 명령어 사용
# python predict.py --images images/people-walking-on-pedestrian-lane-during-daytime-3.jpg
# Out:
# OpenPifPaf version 0.13.11
# PyTorch version 1.13.1+cu117
# device : cpu
# shufflenetv2k30
# cpu
# 0it [00:00, ?it/s]src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# 1it [00:17, 17.76s/it]

# %%
from PIL import Image
import IPython.display as display

# %%
# 이미지 파일 열기
img1 = Image.open('/content/looking/output/_2024-04-04_11-45-17/three_people..predictions.png')
img2 = Image.open('/content/looking/output/_2024-04-04_11-45-46/four_people..predictions.png')
img3 = Image.open('/content/looking/output/_2024-04-04_11-46-17/five_people..predictions.png')

# 이미지 시각화
display.display(img1)
display.display(img2)
display.display(img3)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x266>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1256x542>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1262x612>

# %%
# !python --version
# Out:
# Python 3.10.12
